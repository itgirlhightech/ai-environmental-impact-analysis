# %%
import pandas as pd
import numpy as np

df = pd.read_csv(r'../data/raw/ai_adoption_dataset.csv')
df.head(25)
# Out:
#         country        industry           ai_tool  adoption_rate  \
# 0           USA      Technology           ChatGPT          40.45
# 1        France   Manufacturing        Midjourney          35.72
# 2     Australia  Transportation           ChatGPT          13.47
# 3            UK   Manufacturing           ChatGPT          48.46
# 4            UK     Agriculture  Stable Diffusion          34.06
# 5        Brazil       Education        Midjourney          64.54
# 6           USA      Healthcare              Bard          81.83
# 7     Australia       Education           ChatGPT          20.85
# 8         China          Retail        Midjourney          39.90
# 9           USA     Agriculture        Midjourney          20.53
# 10       Canada       Education        Midjourney          24.10
# 11  South Korea      Technology        Midjourney          58.21
# 12       France   Manufacturing        Midjourney          92.16
# ...

# %%
import pandas as pd
import numpy as np

df = pd.read_csv(r"../data/raw/MEC02.20260316203407.csv")
df.head()
# Out:
#   STATISTIC Statistic Label TLIST(Q1) Quarter C03907V04659  \
# 0     MEC02  Gigawatt hours    2015Q1  2015Q1            -
# 1     MEC02  Gigawatt hours    2015Q1  2015Q1           10
# 2     MEC02  Gigawatt hours    2015Q1  2015Q1           20
# 3     MEC02  Gigawatt hours    2015Q2  2015Q2            -
# 4     MEC02  Gigawatt hours    2015Q2  2015Q2           10
#
#                Electricity Consumption UNIT  VALUE
# 0  All metered electricity consumption  GWh   6565
# 1                         Data centres  GWh    290
# 2    Customers other than data centres  GWh   6275
# 3  All metered electricity consumption  GWh   6086
# 4                         Data centres  GWh    303

# %%
import pandas as pd

df = pd.read_csv(r"../data/raw/WEO2025_AnnexA_Free_Dataset_World.csv")
df.head()
# Out:
#                  PUBLICATION                   SCENARIO CATEGORY PRODUCT  \
# 0  World Energy Outlook 2025                 Historical   Energy   Total
# 1  World Energy Outlook 2025                 Historical   Energy   Total
# 2  World Energy Outlook 2025                 Historical   Energy   Total
# 3  World Energy Outlook 2025  Current Policies Scenario   Energy   Total
# 4  World Energy Outlook 2025  Current Policies Scenario   Energy   Total
#
#                   FLOW UNIT REGION  YEAR    VALUE
# 0  Total energy supply   EJ  World  2010  536.406
# 1  Total energy supply   EJ  World  2023  640.738
# 2  Total energy supply   EJ  World  2024  654.245
# 3  Total energy supply   EJ  World  2035  744.085
# 4  Total energy supply   EJ  World  2040  776.503
